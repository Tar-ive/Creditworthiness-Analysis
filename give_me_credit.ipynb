# %% [markdown]
# <a href="https://colab.research.google.com/github/Tar-ive/Creditworthiness-Analysis/blob/main/give_me_credit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# Create the .kaggle directory
# !mkdir -p ~/.kaggle

# Move the kaggle.json file to the .kaggle directory
# !mv '/content/kaggle (1).json' ~/.kaggle/kaggle.json

# Set the permissions for the file
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c GiveMeSomeCredit

# !unzip GiveMeSomeCredit.zip
# Out:
# ...
#  97% 5.00M/5.16M [00:00<00:00, 40.8MB/s]
# 100% 5.16M/5.16M [00:00<00:00, 38.8MB/s]
# Archive:  GiveMeSomeCredit.zip
#   inflating: Data Dictionary.xls
#   inflating: cs-test.csv
#   inflating: cs-training.csv
#   inflating: sampleEntry.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('cs-test.csv')

# %%
df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1               NaN                              0.885519
# 1                2               NaN                              0.463295
# 2                3               NaN                              0.043275
# 3                4               NaN                              0.280308
# 4                5               NaN                              1.000000
# ...            ...               ...                                   ...
# 101498      101499               NaN                              0.282653
# 101499      101500               NaN                              0.922156
# 101500      101501               NaN                              0.081596
# 101501      101502               NaN                              0.335457
# 101502      101503               NaN                              0.441842
#
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101503.000000               0.0                         101503.000000
# mean    50752.000000               NaN                              5.310000
# std     29301.536524               NaN                            196.156039
# min         1.000000               NaN                              0.000000
# 25%     25376.500000               NaN                              0.030131
# 50%     50752.000000               NaN                              0.152586
# 75%     76127.500000               NaN                              0.564225
# max    101503.000000               NaN                          21821.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101503.000000                         101503.000000  101503.000000
# mean       52.405436                              0.453770     344.475020
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101503.000000               0.0                         101503.000000
# mean    50752.000000               NaN                              5.310000
# std     29301.536524               NaN                            196.156039
# min         1.000000               NaN                              0.000000
# 25%     25376.500000               NaN                              0.030131
# 50%     50752.000000               NaN                              0.152586
# 75%     76127.500000               NaN                              0.564225
# max    101503.000000               NaN                          21821.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101503.000000                         101503.000000  101503.000000
# mean       52.405436                              0.453770     344.475020
# ...

# %%
df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1               NaN                              0.885519
# 1                2               NaN                              0.463295
# 2                3               NaN                              0.043275
# 3                4               NaN                              0.280308
# 4                5               NaN                              1.000000
# ...            ...               ...                                   ...
# 101498      101499               NaN                              0.282653
# 101499      101500               NaN                              0.922156
# 101500      101501               NaN                              0.081596
# 101501      101502               NaN                              0.335457
# 101502      101503               NaN                              0.441842
#
# ...

# %%
df_cleaned = df.dropna()

# Check the number of rows removed
print(f"Original number of rows: {df.shape[0]}")
print(f"Number of rows after removing missing values: {df_cleaned.shape[0]}")
# Out:
# Original number of rows: 101503
# Number of rows after removing missing values: 0

# %%
df_cleaned
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SeriousDlqin2yrs, RevolvingUtilizationOfUnsecuredLines, age, NumberOfTime30-59DaysPastDueNotWorse, DebtRatio, MonthlyIncome, NumberOfOpenCreditLinesAndLoans, NumberOfTimes90DaysLate, NumberRealEstateLoansOrLines, NumberOfTime60-89DaysPastDueNotWorse, NumberOfDependents]
# Index: []

# %%
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# SeriousDlqin2yrs                        101503
# MonthlyIncome                            20103
# NumberOfDependents                        2626
# Unnamed: 0                                   0
# age                                          0
# RevolvingUtilizationOfUnsecuredLines         0
# DebtRatio                                    0
# NumberOfTime30-59DaysPastDueNotWorse         0
# NumberOfOpenCreditLinesAndLoans              0
# NumberOfTimes90DaysLate                      0
# NumberRealEstateLoansOrLines                 0
# NumberOfTime60-89DaysPastDueNotWorse         0
# dtype: int64

# %%
missing_income_percentage = df['MonthlyIncome'].isnull().mean() * 100
missing_income_percentage
# Out:
# 19.805325950957116

# %%
df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1               NaN                              0.885519
# 1                2               NaN                              0.463295
# 2                3               NaN                              0.043275
# 3                4               NaN                              0.280308
# 4                5               NaN                              1.000000
# ...            ...               ...                                   ...
# 101498      101499               NaN                              0.282653
# 101499      101500               NaN                              0.922156
# 101500      101501               NaN                              0.081596
# 101501      101502               NaN                              0.335457
# 101502      101503               NaN                              0.441842
#
# ...

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='median')
df['MonthlyIncome'] = imputer.fit_transform(df[['MonthlyIncome']])

# %%
no_of_depn_percentage = df['NumberOfDependents'].isnull().mean() * 100
no_of_depn_percentage
# Out:
# 2.5871156517541354

# %%
import matplotlib.pyplot as plt

# %%
# Plotting the no of dependents
plt.figure(figsize=(10, 6))
df['NumberOfDependents'].hist(bins=50)
plt.title('Distribution of NumberOfDependents')
plt.xlabel('NumberOfDependents')
plt.ylabel('Frequency')
plt.show()

# Calculating skewnessof the data
dependents_skewness = df['NumberOfDependents'].skew()
dependents_skewness
# Out:
# 2.0759272210251174

# %%
#Dropping unnecessary columns
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                    NaN                              0.885519   43
# 1                    NaN                              0.463295   57
# 2                    NaN                              0.043275   59
# 3                    NaN                              0.280308   38
# 4                    NaN                              1.000000   27
# ...                  ...                                   ...  ...
# 101498               NaN                              0.282653   24
# 101499               NaN                              0.922156   36
# 101500               NaN                              0.081596   70
# 101501               NaN                              0.335457   56
# 101502               NaN                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
df = df.dropna(subset=['NumberOfDependents'])

# %%
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                    NaN                              0.885519   43
# 1                    NaN                              0.463295   57
# 2                    NaN                              0.043275   59
# 3                    NaN                              0.280308   38
# 4                    NaN                              1.000000   27
# ...                  ...                                   ...  ...
# 101497               NaN                              0.045230   67
# 101498               NaN                              0.282653   24
# 101499               NaN                              0.922156   36
# 101501               NaN                              0.335457   56
# 101502               NaN                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# SeriousDlqin2yrs                        98877
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                               0
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                          0
# dtype: int64

# %%
data = pd.read_csv('/content/cs-training.csv')

# %%
data.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines           age  \
# count               0.0                          98877.000000  98877.000000
# mean                NaN                              5.346712     52.214721
# std                 NaN                            197.534257     14.607745
# min                 NaN                              0.000000     21.000000
# 25%                 NaN                              0.031184     41.000000
# 50%                 NaN                              0.157024     52.000000
# 75%                 NaN                              0.567767     63.000000
# max                 NaN                          21821.000000    104.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                          98877.000000   98877.000000   9.887700e+04
# mean                               0.439364     328.824671   6.597851e+03
# ...

# %%
# Calculating correlation matrices to check the data
original_corr = data.corr()
cleaned_corr = df.corr()

import seaborn as sns
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.title('Original Dataset Correlation Matrix')
sns.heatmap(original_corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=False)

plt.subplot(1, 2, 2)
plt.title('Cleaned Dataset Correlation Matrix')
sns.heatmap(cleaned_corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=False)

plt.show()

# %%
df.columns
# Out:
# Index(['SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %%
#creating a new feature
df['TotalPastDueIncidents'] = (df['NumberOfTime30-59DaysPastDueNotWorse'] +
                                         df['NumberOfTimes90DaysLate'] +
                                         df['NumberOfTime60-89DaysPastDueNotWorse'])
# Out:
# <ipython-input-26-e2ac9872f7d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalPastDueIncidents'] = (df['NumberOfTime30-59DaysPastDueNotWorse'] +

# %%
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                    NaN                              0.885519   43
# 1                    NaN                              0.463295   57
# 2                    NaN                              0.043275   59
# 3                    NaN                              0.280308   38
# 4                    NaN                              1.000000   27
# ...                  ...                                   ...  ...
# 101497               NaN                              0.045230   67
# 101498               NaN                              0.282653   24
# 101499               NaN                              0.922156   36
# 101501               NaN                              0.335457   56
# 101502               NaN                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
df.columns
# Out:
# Index(['SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents', 'TotalPastDueIncidents'],
#       dtype='object')

# %%
test_df = pd.read_csv('/content/cs-test.csv')

# %%
test_df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1               NaN                              0.885519
# 1                2               NaN                              0.463295
# 2                3               NaN                              0.043275
# 3                4               NaN                              0.280308
# 4                5               NaN                              1.000000
# ...            ...               ...                                   ...
# 101498      101499               NaN                              0.282653
# 101499      101500               NaN                              0.922156
# 101500      101501               NaN                              0.081596
# 101501      101502               NaN                              0.335457
# 101502      101503               NaN                              0.441842
#
# ...

# %%
print(test_df.isnull().sum().sort_values(ascending=False))
# Out:
# SeriousDlqin2yrs                        101503
# MonthlyIncome                            20103
# NumberOfDependents                        2626
# Unnamed: 0                                   0
# age                                          0
# RevolvingUtilizationOfUnsecuredLines         0
# DebtRatio                                    0
# NumberOfTime30-59DaysPastDueNotWorse         0
# NumberOfOpenCreditLinesAndLoans              0
# NumberOfTimes90DaysLate                      0
# NumberRealEstateLoansOrLines                 0
# NumberOfTime60-89DaysPastDueNotWorse         0
# dtype: int64

# %%
z= test_df['SeriousDlqin2yrs'].value_counts()
z
# Out:
# Series([], Name: count, dtype: int64)

# %%
print(test_df.isnull().sum().sort_values(ascending=False))
# Out:
# SeriousDlqin2yrs                        101503
# MonthlyIncome                            20103
# NumberOfDependents                        2626
# Unnamed: 0                                   0
# age                                          0
# RevolvingUtilizationOfUnsecuredLines         0
# DebtRatio                                    0
# NumberOfTime30-59DaysPastDueNotWorse         0
# NumberOfOpenCreditLinesAndLoans              0
# NumberOfTimes90DaysLate                      0
# NumberRealEstateLoansOrLines                 0
# NumberOfTime60-89DaysPastDueNotWorse         0
# dtype: int64

# %%
test_df = test_df.dropna(subset=['NumberOfDependents'])

# %%
imputer = SimpleImputer(strategy='median')
test_df['MonthlyIncome'] = imputer.fit_transform(df[['MonthlyIncome']])
# Out:
# <ipython-input-35-11581824e48b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MonthlyIncome'] = imputer.fit_transform(df[['MonthlyIncome']])

# %%
print(test_df.isnull().sum().sort_values(ascending=False))
# Out:
# SeriousDlqin2yrs                        98877
# Unnamed: 0                                  0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                               0
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                          0
# dtype: int64

# %%
test_df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1               NaN                              0.885519
# 1                2               NaN                              0.463295
# 2                3               NaN                              0.043275
# 3                4               NaN                              0.280308
# 4                5               NaN                              1.000000
# ...            ...               ...                                   ...
# 101497      101498               NaN                              0.045230
# 101498      101499               NaN                              0.282653
# 101499      101500               NaN                              0.922156
# 101501      101502               NaN                              0.335457
# 101502      101503               NaN                              0.441842
#
# ...

# %%
test_df = test_df.drop(columns=['SeriousDlqin2yrs'])

# %%
test_df
# Out:
#         Unnamed: 0  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                1                              0.885519   43
# 1                2                              0.463295   57
# 2                3                              0.043275   59
# 3                4                              0.280308   38
# 4                5                              1.000000   27
# ...            ...                                   ...  ...
# 101497      101498                              0.045230   67
# 101498      101499                              0.282653   24
# 101499      101500                              0.922156   36
# 101501      101502                              0.335457   56
# 101502      101503                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                    NaN                              0.885519   43
# 1                    NaN                              0.463295   57
# 2                    NaN                              0.043275   59
# 3                    NaN                              0.280308   38
# 4                    NaN                              1.000000   27
# ...                  ...                                   ...  ...
# 101497               NaN                              0.045230   67
# 101498               NaN                              0.282653   24
# 101499               NaN                              0.922156   36
# 101501               NaN                              0.335457   56
# 101502               NaN                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
test_df['TotalPastDueIncidents'] = (test_df['NumberOfTime30-59DaysPastDueNotWorse'] +
                                         test_df['NumberOfTimes90DaysLate'] +
                                         test_df['NumberOfTime60-89DaysPastDueNotWorse'])

# %%
test_df
# Out:
#         Unnamed: 0  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                1                              0.885519   43
# 1                2                              0.463295   57
# 2                3                              0.043275   59
# 3                4                              0.280308   38
# 4                5                              1.000000   27
# ...            ...                                   ...  ...
# 101497      101498                              0.045230   67
# 101498      101499                              0.282653   24
# 101499      101500                              0.922156   36
# 101501      101502                              0.335457   56
# 101502      101503                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
df.columns
# Out:
# Index(['SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents', 'TotalPastDueIncidents'],
#       dtype='object')

# %%
features = ['RevolvingUtilizationOfUnsecuredLines', 'age',
            'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
            'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
            'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
            'NumberOfDependents', 'TotalPastDueIncidents']

target = 'SeriousDlqin2yrs'

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = df[features]
y_train = df[target]
X_train_scaled = scaler.fit_transform(X_train)

#standerdizing the data
X_test = test_df[features]
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score

# %%
from sklearn.preprocessing import StandardScaler

# %%
features = ['RevolvingUtilizationOfUnsecuredLines', 'age',
            'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
            'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
            'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
            'NumberOfDependents', 'TotalPastDueIncidents']

# %%
combined_data = pd.concat([df[features], test_df[features]])

scaler = StandardScaler()

scaler.fit(combined_data)

df_scaled = scaler.transform(df[features])
test_df_scaled = scaler.transform(test_df[features])

df_scaled = pd.DataFrame(df_scaled, columns=features)
test_df_scaled = pd.DataFrame(test_df_scaled, columns=features)

print("Scaled df:")
print(df_scaled.head())
print("\nScaled test_df:")
print(test_df_scaled.head())
# Out:
# Scaled df:
#    RevolvingUtilizationOfUnsecuredLines       age  \
# 0                             -0.022585 -0.630814
# 1                             -0.024722  0.327587
# 2                             -0.026848  0.464501
# 3                             -0.025648 -0.973100
# 4                             -0.022005 -1.726129
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                             -0.101008  -0.200881      -0.027101
# 1                             -0.101008  -0.200667       0.076763
# 2                             -0.101008  -0.200569      -0.045725
# 3                              0.128887  -0.200423      -0.102562
# 4                             -0.101008  -0.200977      -0.082489
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                        -0.880751                -0.064727
# 1                         1.258562                -0.064727
# 2                         0.675113                -0.064727
# ...

# %%
df_scaled
# Out:
#        RevolvingUtilizationOfUnsecuredLines       age  \
# 0                                 -0.022585 -0.630814
# 1                                 -0.024722  0.327587
# 2                                 -0.026848  0.464501
# 3                                 -0.025648 -0.973100
# 4                                 -0.022005 -1.726129
# ...                                     ...       ...
# 98872                             -0.026838  1.012159
# 98873                             -0.025636 -1.931500
# 98874                             -0.022399 -1.110014
# 98875                             -0.025369  0.259130
# 98876                             -0.024831 -1.589214
#
#        NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                 -0.101008  -0.200881      -0.027101
# 1                                 -0.101008  -0.200667       0.076763
# 2                                 -0.101008  -0.200569      -0.045725
# ...

# %%
test_df_scaled
# Out:
#        RevolvingUtilizationOfUnsecuredLines       age  \
# 0                                 -0.022585 -0.630814
# 1                                 -0.024722  0.327587
# 2                                 -0.026848  0.464501
# 3                                 -0.025648 -0.973100
# 4                                 -0.022005 -1.726129
# ...                                     ...       ...
# 98872                             -0.026838  1.012159
# 98873                             -0.025636 -1.931500
# 98874                             -0.022399 -1.110014
# 98875                             -0.025369  0.259130
# 98876                             -0.024831 -1.589214
#
#        NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                 -0.101008  -0.200881      -0.027101
# 1                                 -0.101008  -0.200667       0.076763
# 2                                 -0.101008  -0.200569      -0.045725
# ...

# %%
mean_df_scaled = df_scaled.mean()
mean_df_scaled
# Out:
# RevolvingUtilizationOfUnsecuredLines   -2.766659e-18
# age                                     7.416084e-17
# NumberOfTime30-59DaysPastDueNotWorse   -4.886567e-18
# DebtRatio                               4.599122e-18
# MonthlyIncome                           1.348297e-17
# NumberOfOpenCreditLinesAndLoans        -1.132534e-16
# NumberOfTimes90DaysLate                -5.209942e-18
# NumberRealEstateLoansOrLines            1.019352e-16
# NumberOfTime60-89DaysPastDueNotWorse    1.634844e-17
# NumberOfDependents                      1.008034e-16
# TotalPastDueIncidents                   3.143931e-17
# dtype: float64

# %%
std_df_scaled = df_scaled.std()
std_df_scaled
# Out:
# RevolvingUtilizationOfUnsecuredLines    1.000005
# age                                     1.000005
# NumberOfTime30-59DaysPastDueNotWorse    1.000005
# DebtRatio                               1.000005
# MonthlyIncome                           1.000005
# NumberOfOpenCreditLinesAndLoans         1.000005
# NumberOfTimes90DaysLate                 1.000005
# NumberRealEstateLoansOrLines            1.000005
# NumberOfTime60-89DaysPastDueNotWorse    1.000005
# NumberOfDependents                      1.000005
# TotalPastDueIncidents                   1.000005
# dtype: float64

# %%
mean1_df_scaled= test_df_scaled.mean()
mean1_df_scaled
# Out:
# RevolvingUtilizationOfUnsecuredLines   -2.766659e-18
# age                                     7.416084e-17
# NumberOfTime30-59DaysPastDueNotWorse   -4.886567e-18
# DebtRatio                               4.599122e-18
# MonthlyIncome                           1.348297e-17
# NumberOfOpenCreditLinesAndLoans        -1.132534e-16
# NumberOfTimes90DaysLate                -5.209942e-18
# NumberRealEstateLoansOrLines            1.019352e-16
# NumberOfTime60-89DaysPastDueNotWorse    1.634844e-17
# NumberOfDependents                      1.008034e-16
# TotalPastDueIncidents                   3.143931e-17
# dtype: float64

# %%
std1_df_scaled = test_df_scaled.std()
std1_df_scaled
# Out:
# RevolvingUtilizationOfUnsecuredLines    1.000005
# age                                     1.000005
# NumberOfTime30-59DaysPastDueNotWorse    1.000005
# DebtRatio                               1.000005
# MonthlyIncome                           1.000005
# NumberOfOpenCreditLinesAndLoans         1.000005
# NumberOfTimes90DaysLate                 1.000005
# NumberRealEstateLoansOrLines            1.000005
# NumberOfTime60-89DaysPastDueNotWorse    1.000005
# NumberOfDependents                      1.000005
# TotalPastDueIncidents                   1.000005
# dtype: float64

# %%
#Random Forest Regressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_val = train_test_split(df_scaled, test_size=0.2, random_state=42)

model = RandomForestRegressor(random_state=42)

model.fit(X_train, X_train)
y_val_pred = model.predict(X_val)


print("Mean Squared Error:", mean_squared_error(X_val, y_val_pred))
print("R2 Score:", r2_score(X_val, y_val_pred))
# Out:
# Mean Squared Error: 0.02207585525255174
# R2 Score: 0.9702874491009439

# %%
test_predictions = model.predict(test_df_scaled)

print("Predictions on test data:", test_predictions[:10])
# Out:
# Predictions on test data: [[-2.34579934e-02 -6.31498441e-01 -1.01007506e-01 -2.00009006e-01
#   -2.79341407e-02 -8.80750532e-01 -6.47270462e-02 -9.21032101e-01
#   -5.88739639e-02 -6.76517491e-01 -7.52246313e-02]
#  [-2.49716045e-02  2.64606092e-01 -6.65232879e-02 -2.00632794e-01
#    9.25926104e-02  1.26828621e+00 -6.47270462e-02  2.66951696e+00
#   -5.42360473e-02  1.08284969e+00 -6.20844060e-02]
#  [-2.67017843e-02  4.51494203e-01 -1.01007506e-01 -2.00617827e-01
#   -4.32554197e-02  6.67333857e-01 -6.47270462e-02 -2.33948363e-02
#   -5.88739639e-02  1.08284969e+00 -7.52246313e-02]
#  [-2.52575568e-02 -9.65569497e-01  1.19691488e-01 -2.00464607e-01
#   -9.48528657e-02 -3.12860278e-01 -5.54791361e-02  8.74242428e-01
#   -4.49602143e-02 -6.76517491e-01  6.70853806e-03]
#  [-2.30997329e-02 -1.72270595e+00 -9.87085577e-02 -2.00952054e-01
#   -8.08717722e-02 -8.80750532e-01 -6.01030912e-02 -9.21032101e-01
#   -5.65550056e-02  2.03166100e-01 -7.21328136e-02]
# ...

# %%
# Predictions
test_predictions = model.predict(test_df_scaled)


print("Predictions on test data:", test_predictions[:10])
# Out:
# Predictions on test data: [[-2.34579934e-02 -6.31498441e-01 -1.01007506e-01 -2.00009006e-01
#   -2.79341407e-02 -8.80750532e-01 -6.47270462e-02 -9.21032101e-01
#   -5.88739639e-02 -6.76517491e-01 -7.52246313e-02]
#  [-2.49716045e-02  2.64606092e-01 -6.65232879e-02 -2.00632794e-01
#    9.25926104e-02  1.26828621e+00 -6.47270462e-02  2.66951696e+00
#   -5.42360473e-02  1.08284969e+00 -6.20844060e-02]
#  [-2.67017843e-02  4.51494203e-01 -1.01007506e-01 -2.00617827e-01
#   -4.32554197e-02  6.67333857e-01 -6.47270462e-02 -2.33948363e-02
#   -5.88739639e-02  1.08284969e+00 -7.52246313e-02]
#  [-2.52575568e-02 -9.65569497e-01  1.19691488e-01 -2.00464607e-01
#   -9.48528657e-02 -3.12860278e-01 -5.54791361e-02  8.74242428e-01
#   -4.49602143e-02 -6.76517491e-01  6.70853806e-03]
#  [-2.30997329e-02 -1.72270595e+00 -9.87085577e-02 -2.00952054e-01
#   -8.08717722e-02 -8.80750532e-01 -6.01030912e-02 -9.21032101e-01
#   -5.65550056e-02  2.03166100e-01 -7.21328136e-02]
# ...

# %%
# Applying some rules to test data
test_df['score'] = (test_df['MonthlyIncome'] / (test_df['DebtRatio'] + 1)) - (test_df['NumberOfTimes90DaysLate'] * 10)
test_df['score'] = test_df['score'].apply(lambda x: max(0, min(1, x)))

# %%
test_df
# Out:
#         Unnamed: 0  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                1                              0.885519   43
# 1                2                              0.463295   57
# 2                3                              0.043275   59
# 3                4                              0.280308   38
# 4                5                              1.000000   27
# ...            ...                                   ...  ...
# 101497      101498                              0.045230   67
# 101498      101499                              0.282653   24
# 101499      101500                              0.922156   36
# 101501      101502                              0.335457   56
# 101502      101503                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                    NaN                              0.885519   43
# 1                    NaN                              0.463295   57
# 2                    NaN                              0.043275   59
# 3                    NaN                              0.280308   38
# 4                    NaN                              1.000000   27
# ...                  ...                                   ...  ...
# 101497               NaN                              0.045230   67
# 101498               NaN                              0.282653   24
# 101499               NaN                              0.922156   36
# 101501               NaN                              0.335457   56
# 101502               NaN                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0     0.177513         5700.0
# ...

# %%
features = ['RevolvingUtilizationOfUnsecuredLines', 'age',
            'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
            'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
            'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
            'NumberOfDependents']

# Separating features
X = df[features]

# Standardizing them
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
optimal_clusters = 2

# %%
#Doing K means clustering
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# %%
df['SeriousDlqin2yrs'] = clusters

# %%
cluster_0 = df[df['SeriousDlqin2yrs'] == 0]
cluster_1 = df[df['SeriousDlqin2yrs'] == 1]

# %%
df['SeriousDlqin2yrs'] = df['SeriousDlqin2yrs'].apply(lambda x: 1 if x == 1 else 0)

# %%
print(df['SeriousDlqin2yrs'].value_counts())

# %%
from sklearn.manifold import TSNE

# %%
#Reducing dimensionality of the clusters using TSNE
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# %%
tsne_df = pd.DataFrame(data=X_tsne, columns=['TSNE1', 'TSNE2'])
tsne_df['Cluster'] = clusters

# %%
#Visualizing the clusters using TSNE
plt.figure(figsize=(10, 6))
plt.scatter(tsne_df[tsne_df['Cluster'] == 0]['TSNE1'], tsne_df[tsne_df['Cluster'] == 0]['TSNE2'], label='Cluster 0', alpha=0.5)
plt.scatter(tsne_df[tsne_df['Cluster'] == 1]['TSNE1'], tsne_df[tsne_df['Cluster'] == 1]['TSNE2'], label='Cluster 1', alpha=0.5)
plt.xlabel('TSNE1')
plt.ylabel('TSNE2')
plt.title('t-SNE Visualization of Clusters')
plt.legend()
plt.show()

# %%
df['Cluster'] = clusters

# %%
summary_stats = df.groupby('Cluster').mean()
print(summary_stats)

# %%
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=feature, hue='Cluster', element='step', stat='density', common_norm=False)
    plt.title(f'Distribution of {feature} by Cluster')
    plt.show()

# %%
df

# %%
def remove_outliers(df, features):
    for feature in features:
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[feature] >= lower_bound) & (df[feature] <= upper_bound)]
    return df

# %%
df

# %%
df.shape

# %%
df = df[df['DebtRatio'] <= 1]

# %%
df.shape
# Out:
# (77925, 12)

# %%
df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1               NaN                              0.885519
# 1                2               NaN                              0.463295
# 2                3               NaN                              0.043275
# 3                4               NaN                              0.280308
# 4                5               NaN                              1.000000
# ...            ...               ...                                   ...
# 101495      101496               NaN                              0.718874
# 101497      101498               NaN                              0.045230
# 101498      101499               NaN                              0.282653
# 101499      101500               NaN                              0.922156
# 101502      101503               NaN                              0.441842
#
# ...

# %%
features = ['RevolvingUtilizationOfUnsecuredLines',
            'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio',
            'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
            'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
            'NumberOfDependents']

# %%
X = df[features]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X
# Out:
#         RevolvingUtilizationOfUnsecuredLines  \
# 0                                   0.885519
# 1                                   0.463295
# 2                                   0.043275
# 3                                   0.280308
# 4                                   1.000000
# ...                                      ...
# 101495                              0.718874
# 101497                              0.045230
# 101498                              0.282653
# 101499                              0.922156
# 101502                              0.441842
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  \
# 0                                          0   0.177513
# 1                                          0   0.527237
# 2                                          0   0.687648
# 3                                          1   0.925961
# 4                                          0   0.019917
# ...                                      ...        ...
# ...

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.02212222, -0.10116653, -0.55226057, ..., -0.92756376,
#         -0.06347077, -0.73625218],
#        [-0.02436324, -0.10116653,  0.99770815, ...,  2.79799033,
#         -0.06347077,  0.97417525],
#        [-0.02659256, -0.10116653,  1.70864378, ...,  0.00382476,
#         -0.06347077,  0.97417525],
#        ...,
#        [-0.02532203, -0.10116653, -1.03530248, ..., -0.92756376,
#         -0.06347077, -0.73625218],
#        [-0.02192777,  0.50388377,  2.80143532, ...,  0.93521328,
#         -0.06347077,  2.68460268],
#        [-0.02447711, -0.10116653, -0.45739126, ..., -0.92756376,
#         -0.06347077, -0.73625218]])

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
optimal_clusters = 2

# %%
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
clusters = kmeans.fit_predict(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df['Cluster'] = clusters

# %%
# Reduce the dimensionality of the data to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# Create a DataFrame with the t-SNE results and cluster assignments
tsne_df = pd.DataFrame(data=X_tsne, columns=['TSNE1', 'TSNE2'])
tsne_df['Cluster'] = clusters

# Plot the t-SNE results
plt.figure(figsize=(10, 6))
plt.scatter(tsne_df[tsne_df['Cluster'] == 0]['TSNE1'], tsne_df[tsne_df['Cluster'] == 0]['TSNE2'], label='Cluster 0', alpha=0.5)
plt.scatter(tsne_df[tsne_df['Cluster'] == 1]['TSNE1'], tsne_df[tsne_df['Cluster'] == 1]['TSNE2'], label='Cluster 1', alpha=0.5)
plt.xlabel('TSNE1')
plt.ylabel('TSNE2')
plt.title('t-SNE Visualization of Clusters')
plt.legend()
plt.show()

# Calculate summary statistics for each cluster
summary_stats = df.groupby('Cluster').mean()
print(summary_stats)

# Plot distributions of key features for each cluster
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=feature, hue='Cluster', element='step', stat='density', common_norm=False)
    plt.title(f'Distribution of {feature} by Cluster')
    plt.show()
# Out:
#            Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# Cluster
# 0        50771.216949               NaN                              5.063777
# 1        47768.893401               NaN                              1.000000
#
#                age  NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  \
# Cluster
# 0        51.613241                              0.254529   0.302879
# 1        32.746193                             97.989848   0.002945
#
#          MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# Cluster
# 0          7148.111787                         8.588514
# 1          2255.173913                         0.005076
#
#          NumberOfTimes90DaysLate  NumberRealEstateLoansOrLines  \
# Cluster
# 0                       0.093518                      0.998418
# 1                      97.989848                      0.000000
#
#          NumberOfTime60-89DaysPastDueNotWorse  NumberOfDependents
# Cluster
# ...
